# %% [markdown]
# Try using image based optimization

# %% [markdown]
# # Import

# %%
import os
import sys
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torchvision.models as models
import torchvision.transforms as transforms
import torchvision.transforms.functional as F
from IPython.core.debugger import set_trace
from PIL import Image

# %%
sys.path.append('../../')

# %%
from style_transfer.data import *
from style_transfer.models import *

# %% [markdown]
# # Config

# %%
dir_data = Path('../../data')
dir_styl = dir_data/'style'
dir_cont = dir_data/'content'

# %% [markdown]
# # Utility

# %%
def resize_centercrop(img, sz):
    img = F.resize(img, sz)
    img = F.center_crop(img, sz)
    return img

# %% [markdown]
# # Train

# %%
img_cont = Image.open(dir_cont/'artists'/'layne.jpg')
img_styl = Image.open(dir_styl/'dora.jpg')
sz = 256

# %%
img_cont = resize_centercrop(img_cont, sz)
img_styl = resize_centercrop(img_styl, sz)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12,6))
axs[0].imshow(img_cont)
axs[1].imshow(img_styl)

# %% [markdown]
# Initialize combined image

# %%
img_cont = img2tensor(img_cont)
img_xfer = torch.rand_like(img_cont, requires_grad=True)

# %% [markdown]
# Get stuff for optimization

# %%
optimizer = optim.Adam([img_xfer], lr=1e-1)

# %%
def _update():
    optimizer.zero_grad()
    l, metrics = loss(img_xfer, img_cont)            
    l.backward()
    optimizer.step()
    return metrics

# %%
def _fit(num_epochs, step=50):     
    # %matplotlib notebook
    
    fig, ax = plt.subplots(1, 1)
    for num_epoch in range(num_epochs):
        metrics = _update()
        if num_epoch % step == 0:
            print(pd.DataFrame(metrics, index=[num_epoch]).to_string(header=num_epoch == 0,
                                                                     float_format=lambda x: f'{x:14.2f}',
                                                                     col_space=8))       
            ax.imshow(denorm(torch2np(img_xfer[0])))
            fig.canvas.draw()
        
    # %matplotlib inline

# %%
loss = FeatureLoss(models.vgg16(pretrained=True).features, 
                   img_styl, 
                   sz, 
                   [0,1,2,3,4], 
                   [2],
                   [1e8, 1e8, 1e8, 1e8, 1e8],
                   [0])
_fit(1500)
# Out:
# <img src="data:image/png;base64,..." width="640">
#                       l        ls_s[0]        ls_s[1]        ls_s[2]        ls_s[3]        ls_s[4]        ls_c[0]
# 0              38477.52        7406.29       18448.46       12515.55         101.69           5.52           0.00
# 50              1770.16         807.05         493.30         415.46          49.35           5.00           0.00
# 100              691.93         319.72         153.69         182.10          32.56           3.87           0.00
# 150              430.98         178.13          90.34         132.14          26.91           3.46           0.00
# 200              312.03         121.91          62.20         101.50          23.30           3.12           0.00
# 250              280.59         100.68          55.60          98.93          22.39           2.98           0.00
# 300              231.78          79.11          41.58          88.54          19.80           2.74           0.00
# 350              224.95          72.94          41.94          87.65          19.65           2.77           0.00
# 400              230.08          67.19          41.27          99.67          19.30           2.66           0.00
# 450              168.82          57.86          27.00          63.66          17.74           2.55           0.00
# 500              248.73          57.87          37.32         132.33          18.64           2.57           0.00
# 550              164.86          51.06          26.75          67.06          17.43           2.56           0.00
# 600              289.23          48.17          37.87         182.00          18.51           2.68           0.00
# 650              197.35          53.20          37.64          85.94          17.98           2.58           0.00
# 700              212.14          43.59          25.85         123.09          17.11           2.50           0.00
# 750              126.25          39.14          16.40          53.00          15.37           2.35           0.00
# 800              134.93          38.35          20.33          58.17          15.74           2.33           0.00
# 850              449.59          63.92         104.24         257.53          21.08           2.83           0.00
# 900              283.46          56.15          44.11         161.61          18.83           2.75           0.00
# 950              132.65          41.19          20.51          52.81          15.76           2.39           0.00
# 1000              99.98          31.65          12.65          39.53          13.89           2.25           0.00
# 1050              92.39          28.80          11.54          36.26          13.58           2.21           0.00
# 1100              87.27          27.33          10.36          34.10          13.27           2.20           0.00
# 1150             104.36          27.35          13.46          47.56          13.76           2.23           0.00
# 1200             159.89          31.77          29.05          82.09          14.65           2.33           0.00
# 1250             212.51          48.13          44.37          99.95          17.48           2.57           0.00
# 1300             133.83          33.64          20.86          61.92          14.98           2.42           0.00
# 1350              81.77          24.32           9.57          32.72          12.94           2.22           0.00
# 1400              95.00          22.85          14.28          42.78          12.89           2.19           0.00
# 1450              85.41          22.42           9.70          38.32          12.77           2.20           0.00

# %%
loss = FeatureLoss(models.vgg16(pretrained=True).features, 
                   img_styl, 
                   sz, 
                   [0,1,2,3,4], 
                   [2],
                   [1e8, 1e8, 1e8, 1e8, 1e8],
                   [1e3])
_fit(500)
# Out:
# <img src="data:image/png;base64,..." width="640">
#                       l        ls_s[0]        ls_s[1]        ls_s[2]        ls_s[3]        ls_s[4]        ls_c[0]
# 0              27901.94          21.57          15.87          73.08          13.25           2.32       27775.86
# 50              8157.13         434.46         494.49        1607.68          76.29           7.43        5536.77
# 100             6402.01         283.22         341.20        1674.67          77.07           7.61        4018.24
# 150             5849.25         225.48         293.45        1692.21          78.41           7.38        3552.34
# 200             5435.61         197.25         262.58        1648.22          78.42           7.82        3241.32
# 250             5222.87         180.05         248.62        1648.79          79.02           7.89        3058.51
# 300             5091.19         165.46         239.13        1680.79          80.14           8.04        2917.64
# 350             4965.54         157.09         231.15        1656.21          79.01           7.93        2834.16
# 400             4844.56         149.37         222.67        1632.28          79.48           7.97        2752.79
# 450             4822.63         142.22         218.73        1658.74          79.49           7.73        2715.72

# %%
loss = FeatureLoss(models.vgg16(pretrained=True).features, 
                   img_styl, 
                   sz, 
                   [0,1,2,3,4], 
                   [2],
                   [1e8, 1e8, 1e8, 1e8, 1e8],
                   [0])
_fit(500)
# Out:
# <img src="data:image/png;base64,..." width="640">
#                       l        ls_s[0]        ls_s[1]        ls_s[2]        ls_s[3]        ls_s[4]        ls_c[0]
# 0               2063.70         136.34         213.24        1626.73          79.45           7.95           0.00
# 50               212.40          58.25          35.49          94.60          21.25           2.82           0.00
# 100              146.16          41.38          21.75          62.00          18.45           2.58           0.00
# 150              126.70          34.93          17.74          54.14          17.40           2.50           0.00
# 200              119.10          30.61          15.63          53.77          16.64           2.45           0.00
# 250              107.26          27.60          13.76          47.31          16.17           2.42           0.00
# 300              100.10          25.43          12.81          43.61          15.83           2.41           0.00
# 350               97.53          23.63          12.10          43.92          15.51           2.37           0.00
# 400               98.81          22.23          12.24          46.61          15.39           2.35           0.00
# 450               93.71          21.00          11.08          44.17          15.11           2.36           0.00
